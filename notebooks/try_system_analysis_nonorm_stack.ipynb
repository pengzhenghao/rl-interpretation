# %%
### Useful Variables ###

NUM_SEEDS = 20
NUM_AGENTS = 10
SAMPLE_MODE = "top"
NORMALIZE = False
STACK = True

ENV_NAME = "BipedalWalker-v2"
RUN_NAME = "PPO"
DEFAULT_CONFIG = {}

YAML_PATH = "data/300-agents-ppo.yaml"

# %%
import numpy as np

import ray
from ray.rllib.agents.registry import get_agent_class
import yaml
import seaborn as sns

from process_data import make_ordereddict
from process_fft import evaluate_different_agents

# %matplotlib inline
ray.init(ignore_reinit_error=True, log_to_driver=False)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0817 13:44:57.425132 139867590334208 deprecation.py:323] From /home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:61: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2019-08-17 13:44:59,469	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-08-17_13-44-59_467214_30272/logs.
# 2019-08-17 13:44:59,605	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:15104 to respond...
# 2019-08-17 13:44:59,738	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:17827 to respond...
# 2019-08-17 13:44:59,744	INFO services.py:809 -- Starting Redis shard with 10.0 GB max memory.
# 2019-08-17 13:44:59,792	INFO node.py:512 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-08-17_13-44-59_467214_30272/logs.
# 2019-08-17 13:44:59,796	WARNING services.py:1301 -- Warning: Capping object memory store to 20.0GB. To increase this further, specify `object_store_memory` when calling ray.init() or ray start.
# 2019-08-17 13:44:59,799	INFO services.py:1475 -- Starting the Plasma object store with 20.0 GB memory using /dev/shm.
# {'node_ip_address': '10.1.72.24',
#  'redis_address': '10.1.72.24:15104',
#  'object_store_address': '/tmp/ray/session_2019-08-17_13-44-59_467214_30272/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2019-08-17_13-44-59_467214_30272/sockets/raylet',
#  'webui_url': None,
#  'session_dir': '/tmp/ray/session_2019-08-17_13-44-59_467214_30272'}

# %%
def restore(ckpt):
    cls = get_agent_class(RUN_NAME)
    agent = cls(env=ENV_NAME, config=DEFAULT_CONFIG)
    agent.restore(ckpt)
    return agent

# %%
with open(YAML_PATH, 'r') as f:
    checkpoints = yaml.safe_load(f)

# %%
agent_ckpt_dict = make_ordereddict(checkpoints, NUM_AGENTS, 
                                   mode=SAMPLE_MODE)

agent_dict = {
    agent_name: restore(ckpt) 
    for agent_name, ckpt in agent_ckpt_dict.items()
}
# Out:
# W0817 13:45:01.432740 139867590334208 deprecation_wrapper.py:119] From /home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/tune/logger.py:133: The name tf.VERSION is deprecated. Please use tf.version.VERSION instead.
#
# W0817 13:45:01.437826 139867590334208 deprecation_wrapper.py:119] From /home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/tune/logger.py:138: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2019-08-17 13:45:01,460	ERROR log_sync.py:34 -- Log sync requires cluster to be setup with `ray up`.
# 2019-08-17 13:45:01,595	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:01,932	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# W0817 13:45:03.791536 139867590334208 deprecation.py:323] From /home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0817 13:45:04.393636 139867590334208 deprecation.py:323] From /home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2019-08-17 13:45:05,513	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
#
# { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
#   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 4) dtype=float32>,
#   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
#   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 8) dtype=float32>,
#   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
#   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 24) dtype=float32>,
#   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>,
#   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 4) dtype=float32>,
#   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
#   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
#   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
#   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
#
# W0817 13:45:05.589884 139867590334208 deprecation.py:323] From /home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2019-08-17 13:45:06,802	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f34ea4e67b8>}
# 2019-08-17 13:45:06,803	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f34ea4e6a90>}
# 2019-08-17 13:45:06,804	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f34ea4e2a20>}
# 2019-08-17 13:45:06,850	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2019-08-17 13:45:10,996	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:11,007	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# 2019-08-17 13:45:12,836	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f33682edfd0>}
# 2019-08-17 13:45:12,837	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f33682edef0>}
# 2019-08-17 13:45:12,838	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f33682edd68>}
# 2019-08-17 13:45:12,869	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2019-08-17 13:45:17,474	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:17,489	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# 2019-08-17 13:45:19,004	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f2e40ffe400>}
# 2019-08-17 13:45:19,005	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f2e40ffe320>}
# 2019-08-17 13:45:19,006	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f2e40ffe198>}
# 2019-08-17 13:45:19,036	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2019-08-17 13:45:23,385	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:23,395	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# 2019-08-17 13:45:25,289	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f2e03022860>}
# 2019-08-17 13:45:25,290	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f2e03022780>}
# 2019-08-17 13:45:25,291	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f2e03022630>}
# 2019-08-17 13:45:25,329	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2019-08-17 13:45:29,504	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:29,517	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# 2019-08-17 13:45:31,394	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f2de9004cf8>}
# 2019-08-17 13:45:31,395	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f2de9004c18>}
# 2019-08-17 13:45:31,396	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f2de9846c50>}
# 2019-08-17 13:45:31,424	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2019-08-17 13:45:35,563	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:35,577	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# 2019-08-17 13:45:37,023	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f2dc3838128>}
# 2019-08-17 13:45:37,025	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f2dc3838048>}
# 2019-08-17 13:45:37,025	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f2dc380d080>}
# 2019-08-17 13:45:37,062	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2019-08-17 13:45:41,630	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:41,642	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# 2019-08-17 13:45:43,128	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f2d9d015470>}
# 2019-08-17 13:45:43,129	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f2d9d015390>}
# 2019-08-17 13:45:43,130	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f2d9d015208>}
# 2019-08-17 13:45:43,174	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2019-08-17 13:45:46,976	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:46,993	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# 2019-08-17 13:45:49,046	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f2d7b838908>}
# 2019-08-17 13:45:49,047	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f2d7b838828>}
# 2019-08-17 13:45:49,048	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f2d7b838668>}
# 2019-08-17 13:45:49,090	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2019-08-17 13:45:53,148	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:53,167	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# 2019-08-17 13:45:54,824	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f2d6101bcf8>}
# 2019-08-17 13:45:54,826	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f2d6101bc18>}
# 2019-08-17 13:45:54,827	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f2d6101ba58>}
# 2019-08-17 13:45:54,866	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2019-08-17 13:45:58,924	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# 2019-08-17 13:45:58,936	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# 2019-08-17 13:46:01,172	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f2d36fcb128>}
# 2019-08-17 13:46:01,173	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f2d36fcb048>}
# 2019-08-17 13:46:01,175	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f2d36fc1ef0>}
# 2019-08-17 13:46:01,222	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']

# %% [markdown]
# # No Normalize Version

# %%
df = evaluate_different_agents(
    agent_dict, 
    list(range(NUM_SEEDS)), 
    normalize=NORMALIZE,
    stack_rollout=STACK
)
# Out:
# 2019-08-17 13:46:04,928	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 0
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 1
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 2
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 3
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 4
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 5
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 6
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 7
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 8
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 9
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 10
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 11
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 12
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 13
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 14
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 15
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 16
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 17
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 18
# Current Testing Agent: <PPO seed=193 rew=289.17>, Seed: 19
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 0
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 1
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 2
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 3
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 4
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 5
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 6
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 7
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 8
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 9
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 10
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 11
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 12
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 13
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 14
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 15
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 16
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 17
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 18
# Current Testing Agent: <PPO seed=122 rew=289.20>, Seed: 19
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 0
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 1
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 2
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 3
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 4
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 5
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 6
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 7
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 8
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 9
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 10
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 11
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 12
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 13
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 14
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 15
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 16
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 17
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 18
# Current Testing Agent: <PPO seed=289 rew=289.88>, Seed: 19
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 0
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 1
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 2
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 3
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 4
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 5
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 6
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 7
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 8
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 9
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 10
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 11
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 12
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 13
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 14
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 15
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 16
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 17
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 18
# Current Testing Agent: <PPO seed=154 rew=290.68>, Seed: 19
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 0
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 1
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 2
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 3
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 4
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 5
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 6
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 7
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 8
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 9
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 10
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 11
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 12
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 13
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 14
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 15
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 16
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 17
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 18
# Current Testing Agent: <PPO seed=213 rew=291.07>, Seed: 19
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 0
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 1
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 2
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 3
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 4
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 5
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 6
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 7
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 8
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 9
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 10
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 11
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 12
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 13
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 14
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 15
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 16
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 17
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 18
# Current Testing Agent: <PPO seed=180 rew=291.69>, Seed: 19
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 0
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 1
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 2
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 3
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 4
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 5
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 6
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 7
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 8
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 9
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 10
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 11
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 12
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 13
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 14
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 15
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 16
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 17
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 18
# Current Testing Agent: <PPO seed=152 rew=293.22>, Seed: 19
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 0
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 1
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 2
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 3
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 4
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 5
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 6
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 7
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 8
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 9
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 10
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 11
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 12
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 13
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 14
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 15
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 16
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 17
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 18
# Current Testing Agent: <PPO seed=17 rew=294.70>, Seed: 19
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 0
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 1
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 2
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 3
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 4
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 5
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 6
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 7
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 8
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 9
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 10
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 11
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 12
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 13
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 14
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 15
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 16
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 17
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 18
# Current Testing Agent: <PPO seed=292 rew=299.01>, Seed: 19
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 0
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 1
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 2
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 3
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 4
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 5
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 6
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 7
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 8
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 9
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 10
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 11
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 12
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 13
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 14
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 15
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 16
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 17
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 18
# Current Testing Agent: <PPO seed=121 rew=299.35>, Seed: 19

# %%
sns.set_style("ticks")
sns.relplot(x="frequency", y="value", col="agent", 
            row="label", kind="line", data=df)
