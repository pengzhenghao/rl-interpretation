# %%
from reduce_dimension import reduce_dimension, draw
from process_cluster import load_cluster_df
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from process_cluster import ClusterFinder

# %%
cluster_df = load_cluster_df("data/300-agents-ppo_300agents_100rollout_1seed_ad22204c/"
                             "300-agents-ppo_300agents_100rollout_1seed_ad22204c.pkl")

cf = ClusterFinder(cluster_df)
cf.set(9)
prediction = cf.predict()

# %%
df_2d, _ = reduce_dimension(cluster_df, prediction, three_dimensional=False)
draw(df_2d)
# Out:
# Running pca
# Running tsne
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 300 samples in 0.001s...
# [t-SNE] Computed neighbors for 300 samples in 0.018s...
# [t-SNE] Computed conditional probabilities for sample 300 / 300
# [t-SNE] Mean sigma: 6.701390
# [t-SNE] Computed conditional probabilities in 0.045s
# [t-SNE] Iteration 50: error = 58.3510361, gradient norm = 0.5049071 (50 iterations in 0.154s)
# [t-SNE] Iteration 100: error = 55.5446320, gradient norm = 0.4994148 (50 iterations in 0.150s)
# [t-SNE] Iteration 150: error = 54.8702393, gradient norm = 0.5158493 (50 iterations in 0.130s)
# [t-SNE] Iteration 200: error = 56.6376724, gradient norm = 0.4867581 (50 iterations in 0.128s)
# [t-SNE] Iteration 250: error = 55.7226944, gradient norm = 0.5015277 (50 iterations in 0.129s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.722694
# [t-SNE] Iteration 300: error = 0.4473254, gradient norm = 0.0141466 (50 iterations in 0.115s)
# ...

# %%
df_3d, _ = reduce_dimension(cluster_df, prediction, three_dimensional=True)
draw(df_3d)
# Out:
# Running pca
# Running tsne
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 300 samples in 0.001s...
# [t-SNE] Computed neighbors for 300 samples in 0.017s...
# [t-SNE] Computed conditional probabilities for sample 300 / 300
# [t-SNE] Mean sigma: 7.489607
# [t-SNE] Computed conditional probabilities in 0.047s
# [t-SNE] Iteration 50: error = 68.5046463, gradient norm = 0.3279417 (50 iterations in 0.650s)
# [t-SNE] Iteration 100: error = 85.3854141, gradient norm = 0.2710037 (50 iterations in 0.605s)
# [t-SNE] Iteration 150: error = 96.5538712, gradient norm = 0.2340017 (50 iterations in 0.572s)
# [t-SNE] Iteration 200: error = 104.4684296, gradient norm = 0.2115046 (50 iterations in 0.579s)
# [t-SNE] Iteration 250: error = 109.7900467, gradient norm = 0.2082666 (50 iterations in 0.575s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 109.790047
# [t-SNE] Iteration 300: error = 3.2111461, gradient norm = 0.0004988 (50 iterations in 0.799s)
# ...
