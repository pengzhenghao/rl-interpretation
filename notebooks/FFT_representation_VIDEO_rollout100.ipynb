# %%
### Useful Variables ###

NUM_SEEDS = 1
NUM_ROLLOUTS = 100
NUM_AGENTS = 50
SAMPLE_MODE = "top"
NUM_WORKER = 10
NORMALIZE = "range"
# STACK = False

ENV_NAME = "BipedalWalker-v2"
RUN_NAME = "PPO"
DEFAULT_CONFIG = {}


YAML_PATH = "data/300-agents-ppo.yaml"

# %%
from gym.envs.box2d import BipedalWalker

from process_fft import get_fft_cluster_finder, get_fft_representation
from cluster_video import generate_video_of_cluster
from process_data import get_name_ckpt_mapping


env_maker = BipedalWalker
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0823 21:49:29.308178 140301504661248 deprecation.py:323] From /home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:61: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
ret = get_fft_cluster_finder(
    YAML_PATH,
    ENV_NAME,
    env_maker,
    RUN_NAME,
    NORMALIZE,
    NUM_AGENTS,
    NUM_SEEDS,
    NUM_ROLLOUTS,
    show=True
)
# Out:
# Successfully loaded name_ckpt_mapping!
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=187 rew=282.21>
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=98 rew=282.24>
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=203 rew=282.25>
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=197 rew=282.48>
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=71 rew=282.55>
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=283 rew=282.79>
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=116 rew=283.13>
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=70 rew=283.20>
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=201 rew=283.28>
# [1/50] (+0.0s/0.0s) Start collecting data from agent <PPO seed=113 rew=283.29>
# [1/50] (+328.1s/328.1s) Got data from agent <PPO seed=187 rew=282.21>
# [2/50] (+0.2s/328.3s) Got data from agent <PPO seed=98 rew=282.24>
# [3/50] (+0.3s/328.6s) Got data from agent <PPO seed=203 rew=282.25>
# [4/50] (+0.2s/328.9s) Got data from agent <PPO seed=197 rew=282.48>
# [5/50] (+0.3s/329.1s) Got data from agent <PPO seed=71 rew=282.55>
# [6/50] (+0.2s/329.4s) Got data from agent <PPO seed=283 rew=282.79>
# [7/50] (+0.3s/329.6s) Got data from agent <PPO seed=116 rew=283.13>
# [8/50] (+0.2s/329.9s) Got data from agent <PPO seed=70 rew=283.20>
# [9/50] (+0.2s/330.1s) Got data from agent <PPO seed=201 rew=283.28>
# [10/50] (+0.2s/330.3s) Got data from agent <PPO seed=113 rew=283.29>
# [11/50] (+330.3s/330.3s) Start collecting data from agent <PPO seed=7 rew=283.41>
# [11/50] (+0.0s/330.4s) Start collecting data from agent <PPO seed=128 rew=283.51>
# [11/50] (+0.0s/330.4s) Start collecting data from agent <PPO seed=125 rew=283.66>
# [11/50] (+0.0s/330.4s) Start collecting data from agent <PPO seed=159 rew=283.72>
# [11/50] (+0.0s/330.4s) Start collecting data from agent <PPO seed=112 rew=283.85>
# [11/50] (+0.0s/330.4s) Start collecting data from agent <PPO seed=81 rew=283.91>
# [11/50] (+0.0s/330.4s) Start collecting data from agent <PPO seed=88 rew=283.96>
# [11/50] (+0.0s/330.4s) Start collecting data from agent <PPO seed=250 rew=284.10>
# [11/50] (+0.0s/330.4s) Start collecting data from agent <PPO seed=160 rew=284.55>
# [11/50] (+0.0s/330.4s) Start collecting data from agent <PPO seed=149 rew=284.60>
# [11/50] (+303.2s/633.6s) Got data from agent <PPO seed=7 rew=283.41>
# [12/50] (+0.3s/633.8s) Got data from agent <PPO seed=128 rew=283.51>
# [13/50] (+0.4s/634.2s) Got data from agent <PPO seed=125 rew=283.66>
# [14/50] (+10.7s/644.9s) Got data from agent <PPO seed=159 rew=283.72>
# [15/50] (+0.2s/645.1s) Got data from agent <PPO seed=112 rew=283.85>
# [16/50] (+0.2s/645.3s) Got data from agent <PPO seed=81 rew=283.91>
# [17/50] (+0.3s/645.6s) Got data from agent <PPO seed=88 rew=283.96>
# [18/50] (+0.2s/645.8s) Got data from agent <PPO seed=250 rew=284.10>
# [19/50] (+0.2s/646.0s) Got data from agent <PPO seed=160 rew=284.55>
# [20/50] (+0.3s/646.3s) Got data from agent <PPO seed=149 rew=284.60>
# [21/50] (+316.0s/646.3s) Start collecting data from agent <PPO seed=76 rew=284.69>
# [21/50] (+0.0s/646.3s) Start collecting data from agent <PPO seed=147 rew=285.01>
# [21/50] (+0.0s/646.3s) Start collecting data from agent <PPO seed=273 rew=285.04>
# [21/50] (+0.0s/646.3s) Start collecting data from agent <PPO seed=85 rew=285.43>
# [21/50] (+0.0s/646.3s) Start collecting data from agent <PPO seed=267 rew=285.54>
# [21/50] (+0.0s/646.3s) Start collecting data from agent <PPO seed=178 rew=285.63>
# [21/50] (+0.0s/646.3s) Start collecting data from agent <PPO seed=73 rew=285.69>
# [21/50] (+0.0s/646.3s) Start collecting data from agent <PPO seed=20 rew=285.95>
# [21/50] (+0.0s/646.4s) Start collecting data from agent <PPO seed=38 rew=286.04>
# [21/50] (+0.0s/646.4s) Start collecting data from agent <PPO seed=104 rew=286.29>
# [21/50] (+254.9s/901.2s) Got data from agent <PPO seed=76 rew=284.69>
# [22/50] (+26.0s/927.2s) Got data from agent <PPO seed=147 rew=285.01>
# [23/50] (+0.2s/927.4s) Got data from agent <PPO seed=273 rew=285.04>
# [24/50] (+10.5s/938.0s) Got data from agent <PPO seed=85 rew=285.43>
# [25/50] (+0.3s/938.2s) Got data from agent <PPO seed=267 rew=285.54>
# [26/50] (+0.2s/938.5s) Got data from agent <PPO seed=178 rew=285.63>
# [27/50] (+3.0s/941.5s) Got data from agent <PPO seed=73 rew=285.69>
# [28/50] (+0.2s/941.7s) Got data from agent <PPO seed=20 rew=285.95>
# [29/50] (+4.5s/946.2s) Got data from agent <PPO seed=38 rew=286.04>
# [30/50] (+1.6s/947.8s) Got data from agent <PPO seed=104 rew=286.29>
# [31/50] (+301.5s/947.8s) Start collecting data from agent <PPO seed=164 rew=286.42>
# [31/50] (+0.0s/947.8s) Start collecting data from agent <PPO seed=1 rew=286.70>
# [31/50] (+0.0s/947.8s) Start collecting data from agent <PPO seed=146 rew=286.81>
# [31/50] (+0.0s/947.8s) Start collecting data from agent <PPO seed=153 rew=286.99>
# [31/50] (+0.0s/947.8s) Start collecting data from agent <PPO seed=5 rew=287.08>
# [31/50] (+0.0s/947.8s) Start collecting data from agent <PPO seed=26 rew=287.09>
# [31/50] (+0.0s/947.8s) Start collecting data from agent <PPO seed=135 rew=287.60>
# [31/50] (+0.0s/947.8s) Start collecting data from agent <PPO seed=274 rew=288.90>
# [31/50] (+0.0s/947.8s) Start collecting data from agent <PPO seed=188 rew=289.03>
# [31/50] (+0.0s/947.8s) Start collecting data from agent <PPO seed=255 rew=289.15>
# [31/50] (+289.8s/1237.6s) Got data from agent <PPO seed=164 rew=286.42>
# [32/50] (+3.3s/1240.9s) Got data from agent <PPO seed=1 rew=286.70>
# [33/50] (+9.2s/1250.0s) Got data from agent <PPO seed=146 rew=286.81>
# [34/50] (+0.8s/1250.8s) Got data from agent <PPO seed=153 rew=286.99>
# [35/50] (+0.3s/1251.1s) Got data from agent <PPO seed=5 rew=287.08>
# [36/50] (+0.2s/1251.3s) Got data from agent <PPO seed=26 rew=287.09>
# [37/50] (+27.2s/1278.5s) Got data from agent <PPO seed=135 rew=287.60>
# [38/50] (+0.2s/1278.8s) Got data from agent <PPO seed=274 rew=288.90>
# [39/50] (+0.3s/1279.0s) Got data from agent <PPO seed=188 rew=289.03>
# [40/50] (+0.3s/1279.4s) Got data from agent <PPO seed=255 rew=289.15>
# [41/50] (+331.5s/1279.4s) Start collecting data from agent <PPO seed=193 rew=289.17>
# [41/50] (+0.0s/1279.4s) Start collecting data from agent <PPO seed=122 rew=289.20>
# [41/50] (+0.0s/1279.4s) Start collecting data from agent <PPO seed=289 rew=289.88>
# [41/50] (+0.0s/1279.4s) Start collecting data from agent <PPO seed=154 rew=290.68>
# [41/50] (+0.0s/1279.4s) Start collecting data from agent <PPO seed=213 rew=291.07>
# [41/50] (+0.0s/1279.4s) Start collecting data from agent <PPO seed=180 rew=291.69>
# [41/50] (+0.0s/1279.4s) Start collecting data from agent <PPO seed=152 rew=293.22>
# [41/50] (+0.0s/1279.4s) Start collecting data from agent <PPO seed=17 rew=294.70>
# [41/50] (+0.0s/1279.4s) Start collecting data from agent <PPO seed=292 rew=299.01>
# [41/50] (+0.0s/1279.4s) Start collecting data from agent <PPO seed=121 rew=299.35>
# [41/50] (+275.6s/1555.0s) Got data from agent <PPO seed=193 rew=289.17>
# [42/50] (+4.4s/1559.4s) Got data from agent <PPO seed=122 rew=289.20>
# [43/50] (+0.4s/1559.8s) Got data from agent <PPO seed=289 rew=289.88>
# [44/50] (+2.0s/1561.8s) Got data from agent <PPO seed=154 rew=290.68>
# [45/50] (+0.2s/1562.0s) Got data from agent <PPO seed=213 rew=291.07>
# [46/50] (+0.2s/1562.2s) Got data from agent <PPO seed=180 rew=291.69>
# [47/50] (+0.2s/1562.4s) Got data from agent <PPO seed=152 rew=293.22>
# [48/50] (+0.3s/1562.7s) Got data from agent <PPO seed=17 rew=294.70>
# [49/50] (+0.3s/1563.0s) Got data from agent <PPO seed=292 rew=299.01>
# [50/50] (+0.3s/1563.3s) Got data from agent <PPO seed=121 rew=299.35>
# Successfully get FFT representation!
# Successfully get cluster dataframe!
# Successfully store cluster_df! Save at: data/300-agents-ppo_50agents_100rollout_1seed_15473631/300-agents-ppo_50agents_100rollout_1seed_15473631.pkl
# Clustering Finished! Call ClusterFinder.display to see the elbow curve.
# Successfully finish no-standardized clustering! Save at: data/300-agents-ppo_50agents_100rollout_1seed_15473631/300-agents-ppo_50agents_100rollout_1seed_15473631_nostd.png
# Clustering Finished! Call ClusterFinder.display to see the elbow curve.
# Successfully finish standardized clustering! Save at: data/300-agents-ppo_50agents_100rollout_1seed_15473631/300-agents-ppo_50agents_100rollout_1seed_15473631_std.png

# %%
cluster_finder_dict = ret["cluster_finder"]
prefix = ret["prefix"]

# %%
best_k_dict = {
    "nostd_cluster_finder": 5,
    "std_cluster_finder": 5
}

# %%
prediction_dict = {}
for name, cluster_finder in cluster_finder_dict.items():
    best_k = best_k_dict[name]
    cluster_finder.set(best_k)
    prediction = cluster_finder.predict()
    prediction_dict[name] = prediction

# %%
from utils import initialize_ray as init

init()

for name, prediction in prediction_dict.items():
    generate_video_of_cluster(
        prediction,
        ENV_NAME,
        RUN_NAME,
        NUM_AGENTS,
        YAML_PATH,
        video_predix=prefix+name,
    )
# Out:
# Exception ignored in: <bound method ActorHandle.__del__ of Actor(CollectFramesWorker, d0e9d891d5b59aec2f6762fcc8d82d9fbaad14ed)>
# Traceback (most recent call last):
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 632, in __del__
#     self.__ray_terminate__.remote()
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 148, in remote
#     return self._remote(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 169, in _remote
#     return invocation(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 163, in invocation
#     num_return_vals=num_return_vals)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 556, in _actor_method_call
#     job_id=self._ray_actor_job_id,
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py", line 740, in submit_task
#     self.raylet_client.submit_task(task)
#   File "python/ray/_raylet.pyx", line 239, in ray._raylet.RayletClient.submit_task
#   File "python/ray/_raylet.pyx", line 61, in ray._raylet.check_status
# ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# Exception ignored in: <bound method ActorHandle.__del__ of Actor(CollectFramesWorker, 963850b4a39d32bc92d65daf1131d26ec70c8b59)>
# Traceback (most recent call last):
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 632, in __del__
#     self.__ray_terminate__.remote()
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 148, in remote
#     return self._remote(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 169, in _remote
#     return invocation(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 163, in invocation
#     num_return_vals=num_return_vals)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 556, in _actor_method_call
#     job_id=self._ray_actor_job_id,
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py", line 740, in submit_task
#     self.raylet_client.submit_task(task)
#   File "python/ray/_raylet.pyx", line 239, in ray._raylet.RayletClient.submit_task
#   File "python/ray/_raylet.pyx", line 61, in ray._raylet.check_status
# ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# Exception ignored in: <bound method ActorHandle.__del__ of Actor(CollectFramesWorker, adf50eea9ac2c2f958f747c93bc45334fe0ec086)>
# Traceback (most recent call last):
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 632, in __del__
#     self.__ray_terminate__.remote()
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 148, in remote
#     return self._remote(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 169, in _remote
#     return invocation(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 163, in invocation
#     num_return_vals=num_return_vals)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 556, in _actor_method_call
#     job_id=self._ray_actor_job_id,
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py", line 740, in submit_task
#     self.raylet_client.submit_task(task)
#   File "python/ray/_raylet.pyx", line 239, in ray._raylet.RayletClient.submit_task
#   File "python/ray/_raylet.pyx", line 61, in ray._raylet.check_status
# ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# Exception ignored in: <bound method ActorHandle.__del__ of Actor(CollectFramesWorker, dde66abb5a45c5953d4abe09b4238f1fca06e693)>
# Traceback (most recent call last):
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 632, in __del__
#     self.__ray_terminate__.remote()
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 148, in remote
#     return self._remote(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 169, in _remote
#     return invocation(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 163, in invocation
#     num_return_vals=num_return_vals)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 556, in _actor_method_call
#     job_id=self._ray_actor_job_id,
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py", line 740, in submit_task
#     self.raylet_client.submit_task(task)
#   File "python/ray/_raylet.pyx", line 239, in ray._raylet.RayletClient.submit_task
#   File "python/ray/_raylet.pyx", line 61, in ray._raylet.check_status
# ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# Exception ignored in: <bound method ActorHandle.__del__ of Actor(CollectFramesWorker, 2395b7edffb4911326c0b4abdf81f1c6d4c09f62)>
# Traceback (most recent call last):
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 632, in __del__
#     self.__ray_terminate__.remote()
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 148, in remote
#     return self._remote(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 169, in _remote
#     return invocation(args, kwargs)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 163, in invocation
#     num_return_vals=num_return_vals)
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py", line 556, in _actor_method_call
#     job_id=self._ray_actor_job_id,
#   File "/home/zhpeng/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py", line 740, in submit_task
#     self.raylet_client.submit_task(task)
#   File "python/ray/_raylet.pyx", line 239, in ray._raylet.RayletClient.submit_task
#   File "python/ray/_raylet.pyx", line 61, in ray._raylet.check_status
# ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# ---------------------------------------------------------------------------
# ArrowIOError                              Traceback (most recent call last)
# <ipython-input-12-b02efbe551ee> in <module>
#      10         NUM_AGENTS,
#      11         YAML_PATH,
# ---> 12         video_predix=prefix+name,
#      13     )
#
# ~/novel-rl/cluster_video.py in generate_video_of_cluster(prediction, env_name, run_name, num_agents, yaml_path, video_predix, seed, max_num_cols, local_mode, steps, num_workers)
#     133         name_row_mapping=name_row_mapping,
#     134         name_loc_mapping=name_loc_mapping,
# --> 135         num_workers=num_workers
#     136     )
#     137
#
# ~/novel-rl/record_video.py in generate_frames(self, name_ckpt_mapping, num_steps, num_iters, seed, name_column_mapping, name_row_mapping, name_loc_mapping, args_config, num_workers)
#     183                 self.run_name, ENVIRONMENT_MAPPING[self.env_name],
#     184                 self.env_name, num_steps, num_iters, seed
# --> 185             ) for _ in range(num_workers)
#     186         ]
#     187
#
# ~/novel-rl/record_video.py in <listcomp>(.0)
#     183                 self.run_name, ENVIRONMENT_MAPPING[self.env_name],
#     184                 self.env_name, num_steps, num_iters, seed
# --> 185             ) for _ in range(num_workers)
#     186         ]
#     187
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py in remote(self, *args, **kwargs)
#     276             A handle to the newly created actor.
#     277         """
# --> 278         return self._remote(args=args, kwargs=kwargs)
#     279
#     280     def _remote(self,
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/actor.py in _remote(self, args, kwargs, num_cpus, num_gpus, resources)
#     382                 num_return_vals=1,
#     383                 resources=resources,
# --> 384                 placement_resources=actor_placement_resources)
#     385             assert isinstance(actor_cursor, ObjectID)
#     386
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py in submit_task(self, function_descriptor, args, actor_id, actor_handle_id, actor_counter, actor_creation_id, actor_creation_dummy_object_id, previous_actor_task_dummy_object_id, max_actor_reconstructions, new_actor_handles, num_return_vals, resources, placement_resources, job_id)
#     678                     args_for_raylet.append(arg)
#     679                 else:
# --> 680                     args_for_raylet.append(put(arg))
#     681
#     682             if new_actor_handles is None:
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py in put(value)
#    2275                 worker.task_context.put_index,
#    2276             )
# -> 2277             worker.put_object(object_id, value)
#    2278         worker.task_context.put_index += 1
#    2279         return object_id
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py in put_object(self, object_id, value)
#     396                 range(ray_constants.DEFAULT_PUT_OBJECT_RETRIES)):
#     397             try:
# --> 398                 self._try_store_and_register(object_id, value)
#     399                 break
#     400             except pyarrow.plasma.PlasmaStoreFull as plasma_exc:
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py in _try_store_and_register(self, object_id, value)
#     416         """
#     417         try:
# --> 418             self.store_and_register(object_id, value)
#     419         except pyarrow.plasma.PlasmaObjectExists:
#     420             # The object already exists in the object store, so there is no
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/worker.py in store_and_register(self, object_id, value, depth)
#     325                         memcopy_threads=self.memcopy_threads,
#     326                         serialization_context=self.get_serialization_context(
# --> 327                             self.current_job_id))
#     328                 break
#     329             except pyarrow.SerializationCallbackError as e:
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/utils.py in _wrapper(*args, **kwargs)
#     517                 def _wrapper(*args, **kwargs):
#     518                     with self.lock:
# --> 519                         return orig_attr(*args, **kwargs)
#     520
#     521                 self._wrapper_cache[attr] = _wrapper
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/_plasma.pyx in pyarrow._plasma.PlasmaClient.put()
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/_plasma.pyx in pyarrow._plasma.PlasmaClient.create()
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/_plasma.pyx in pyarrow._plasma.plasma_check_status()
#
# ~/anaconda3/envs/uber/lib/python3.6/site-packages/ray/pyarrow_files/pyarrow/error.pxi in pyarrow.lib.check_status()
#
# ArrowIOError: Broken pipe
